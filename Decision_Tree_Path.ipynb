# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import pandas as pd
from collections import namedtuple
from collections import UserList
from sklearn import tree

# new packages
from collections import defaultdict
from sklearn.datasets import load_diabetes
from sklearn.datasets import load_linnerud
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder, MinMaxScaler
import os

# customized class
from Node import Node
from helper import convert_onehot_v1, preprocess
from load_config import load_yaml, dump_yaml, safe_load_yaml
from decision_tree_more_features import Track_DT

## Initiaze logger
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s :: %(levelname)s :: %(message)s')
logger = logging.getLogger('microsegmenter')

# %%
general_config = safe_load_yaml('general_config.yaml')
sample_data = pd.read_csv(general_config['dataset']['data_path'])
ordinal_encoder = OrdinalEncoder()
onehot_encoder = OneHotEncoder()
X, y, column_names, dtypes, target_names = preprocess(sample_data, ordinal_encoder,
                                     onehot_encoder)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

clf = DecisionTreeClassifier(max_leaf_nodes=general_config['model']['decision_tree']['max_leaf_nodes'],
                          random_state=general_config['model']['decision_tree']['random_state'])
clf.fit(X_train, y_train)

summary_dic = {}
for i, (criteria_key, criteria_value) in enumerate(general_config['criteria'].items()):
    interested_class = criteria_value['interested_class']
    min_samples = criteria_value['min_samples']
    lift = criteria_value['lift']
    base_rate = criteria_value['base_rate']
    tree = Track_DT(clf, column_names, target_names, dtypes, interested_class, min_samples,
             lift, base_rate, rule_outcome_map = {})
    summary_dic[f"summary {i}"] = tree.summary_df
# Out:
# 2022-07-13 10:23:07,341 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,342 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  1 : [0.1]
# 2022-07-13 10:23:07,342 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,342 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,343 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  1 : [0.17857143]
# 2022-07-13 10:23:07,343 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,343 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,344 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  1 : [0.]
# 2022-07-13 10:23:07,344 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,345 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 27
# 2022-07-13 10:23:07,345 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,345 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,346 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,346 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  1 : [0.]
# 2022-07-13 10:23:07,346 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,347 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,348 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,348 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,348 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 11
# 2022-07-13 10:23:07,349 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,349 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,350 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,350 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,350 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,351 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 1. 0. 0.] , 13
# 2022-07-13 10:23:07,351 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,351 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,352 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,352 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,353 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,353 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,353 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  1 : [0.]
# 2022-07-13 10:23:07,354 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,354 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,355 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  1 : [0.17857143]
# 2022-07-13 10:23:07,355 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,356 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,356 :: INFO :: Distribution(%) of interested class in the node : Age -  1 : [0.45454545]
# 2022-07-13 10:23:07,357 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,357 :: INFO :: Appending Rule HIGH_BP > 0.5
# 2022-07-13 10:23:07,358 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,358 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,358 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,359 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,359 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,359 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,360 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [1. 0. 0. 0. 0.] , 18
# 2022-07-13 10:23:07,360 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,360 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,361 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,361 :: INFO :: Distribution(%) of interested class in the node : Age -  1 : [0.45454545]
# 2022-07-13 10:23:07,362 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,362 :: INFO :: Appending Rule HIGH_BP > 0.5
# 2022-07-13 10:23:07,362 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,363 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,363 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,363 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,364 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,364 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,365 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 1. 0. 0. 0.] , 15
# 2022-07-13 10:23:07,365 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [1.]
# 2022-07-13 10:23:07,365 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,366 :: INFO :: Appending Rule Age > 50.5
# 2022-07-13 10:23:07,366 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,367 :: INFO :: Age > 50.5 , node type : int64
# 2022-07-13 10:23:07,367 :: INFO :: Appending Rule HIGH_BP > 0.5
# 2022-07-13 10:23:07,367 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,368 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,368 :: INFO :: Age > 50.5 , node type : int64
# 2022-07-13 10:23:07,368 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,368 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,368 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,369 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,369 :: INFO :: Age > 50.5 , node type : int64
# 2022-07-13 10:23:07,369 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,370 :: INFO :: Distribution(%) of interested class in the node : Age -  1 : [0.45454545]
# 2022-07-13 10:23:07,370 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,371 :: INFO :: Appending Rule HIGH_BP > 0.5
# 2022-07-13 10:23:07,371 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,372 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,372 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,372 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,373 :: INFO :: HIGH_BP > 0.5 , node type : object
# 2022-07-13 10:23:07,373 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,374 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,374 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  1 : [0.17857143]
# 2022-07-13 10:23:07,375 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,375 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,376 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  1 : [0.1]
# 2022-07-13 10:23:07,376 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,376 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 0. 1.] , 66
# 2022-07-13 10:23:07,377 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  1 : [0.]
# 2022-07-13 10:23:07,377 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,379 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,380 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  2 : [0.08666667]
# 2022-07-13 10:23:07,380 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,381 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,381 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  2 : [0.1547619]
# 2022-07-13 10:23:07,381 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,382 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,382 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  2 : [0.25490196]
# 2022-07-13 10:23:07,383 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,383 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 27
# 2022-07-13 10:23:07,384 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.]
# 2022-07-13 10:23:07,384 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,384 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,385 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  2 : [0.25490196]
# 2022-07-13 10:23:07,385 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,386 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,386 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.54166667]
# 2022-07-13 10:23:07,386 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,387 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 11
# 2022-07-13 10:23:07,387 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.]
# 2022-07-13 10:23:07,388 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,388 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,388 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.54166667]
# 2022-07-13 10:23:07,388 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,389 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 1. 0. 0.] , 13
# 2022-07-13 10:23:07,389 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [1.]
# 2022-07-13 10:23:07,390 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,390 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,391 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.54166667]
# 2022-07-13 10:23:07,391 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,391 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,392 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  2 : [0.25490196]
# 2022-07-13 10:23:07,392 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,393 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,393 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  2 : [0.1547619]
# 2022-07-13 10:23:07,393 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,394 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,394 :: INFO :: Distribution(%) of interested class in the node : Age -  2 : [0.]
# 2022-07-13 10:23:07,394 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,395 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [1. 0. 0. 0. 0.] , 18
# 2022-07-13 10:23:07,395 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.]
# 2022-07-13 10:23:07,396 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,396 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,397 :: INFO :: Distribution(%) of interested class in the node : Age -  2 : [0.]
# 2022-07-13 10:23:07,397 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,397 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 1. 0. 0. 0.] , 15
# 2022-07-13 10:23:07,398 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.]
# 2022-07-13 10:23:07,398 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,399 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,399 :: INFO :: Distribution(%) of interested class in the node : Age -  2 : [0.]
# 2022-07-13 10:23:07,400 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,400 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,400 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  2 : [0.1547619]
# 2022-07-13 10:23:07,401 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,401 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,402 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  2 : [0.08666667]
# 2022-07-13 10:23:07,402 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,403 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 0. 1.] , 66
# 2022-07-13 10:23:07,403 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  2 : [0.]
# 2022-07-13 10:23:07,403 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,404 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,405 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  3 : [0.25333333]
# 2022-07-13 10:23:07,405 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,406 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,406 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  3 : [0.45238095]
# 2022-07-13 10:23:07,407 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,407 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,408 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,408 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,409 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,409 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  3 : [0.74509804]
# 2022-07-13 10:23:07,409 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,410 :: INFO :: Appending Rule HIGH_BP <= 0.5
# 2022-07-13 10:23:07,410 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,410 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,410 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,411 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,411 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,411 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,412 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 27
# 2022-07-13 10:23:07,412 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [1.]
# 2022-07-13 10:23:07,413 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,413 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,413 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  3 : [0.74509804]
# 2022-07-13 10:23:07,414 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,414 :: INFO :: Appending Rule HIGH_BP <= 0.5
# 2022-07-13 10:23:07,415 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,415 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,415 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,416 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,416 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,416 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,417 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,417 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.45833333]
# 2022-07-13 10:23:07,418 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,418 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 1. 0.] , 11
# 2022-07-13 10:23:07,418 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [1.]
# 2022-07-13 10:23:07,419 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,419 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,419 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.45833333]
# 2022-07-13 10:23:07,420 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,420 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 1. 0. 0.] , 13
# 2022-07-13 10:23:07,421 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.]
# 2022-07-13 10:23:07,421 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,422 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.54166667 0.45833333 0.        ] , 24
# 2022-07-13 10:23:07,422 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.45833333]
# 2022-07-13 10:23:07,422 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,423 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.         0.         0.25490196 0.74509804 0.        ] , 51
# 2022-07-13 10:23:07,423 :: INFO :: Distribution(%) of interested class in the node : LOW_BP -  3 : [0.74509804]
# 2022-07-13 10:23:07,423 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,424 :: INFO :: Appending Rule HIGH_BP <= 0.5
# 2022-07-13 10:23:07,424 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,425 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,425 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,425 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,426 :: INFO :: HIGH_BP <= 0.5 , node type : object
# 2022-07-13 10:23:07,426 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,427 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,427 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  3 : [0.45238095]
# 2022-07-13 10:23:07,428 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,428 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,428 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,428 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,429 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,429 :: INFO :: Distribution(%) of interested class in the node : Age -  3 : [0.]
# 2022-07-13 10:23:07,430 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,430 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [1. 0. 0. 0. 0.] , 18
# 2022-07-13 10:23:07,430 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.]
# 2022-07-13 10:23:07,430 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,431 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,431 :: INFO :: Distribution(%) of interested class in the node : Age -  3 : [0.]
# 2022-07-13 10:23:07,432 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,432 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 1. 0. 0. 0.] , 15
# 2022-07-13 10:23:07,432 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.]
# 2022-07-13 10:23:07,433 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,433 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.54545455 0.45454545 0.         0.         0.        ] , 33
# 2022-07-13 10:23:07,434 :: INFO :: Distribution(%) of interested class in the node : Age -  3 : [0.]
# 2022-07-13 10:23:07,434 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# 2022-07-13 10:23:07,434 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.21428571 0.17857143 0.1547619  0.45238095 0.        ] , 84
# 2022-07-13 10:23:07,434 :: INFO :: Distribution(%) of interested class in the node : HIGH_BP -  3 : [0.45238095]
# 2022-07-13 10:23:07,435 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,435 :: INFO :: Appending Rule Na_to_K <= 14.828500270843506
# 2022-07-13 10:23:07,435 :: INFO :: List of rules added to decision path so far
# 2022-07-13 10:23:07,436 :: INFO :: Na_to_K <= 14.828500270843506 , node type : float64
# 2022-07-13 10:23:07,437 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0.12       0.1        0.08666667 0.25333333 0.44      ] , 150
# 2022-07-13 10:23:07,437 :: INFO :: Distribution(%) of interested class in the node : Na_to_K -  3 : [0.25333333]
# 2022-07-13 10:23:07,438 :: INFO :: Evaluation of node to meet the microsegmentation criteria : True
# 2022-07-13 10:23:07,438 :: INFO :: Distribution(%) of classes in the node [0 1 2 3 4] and total samples: [0. 0. 0. 0. 1.] , 66
# 2022-07-13 10:23:07,438 :: INFO :: Distribution(%) of interested class in the node : HIGH_Cholesterol -  3 : [0.]
# 2022-07-13 10:23:07,439 :: INFO :: Evaluation of node to meet the microsegmentation criteria : False
# Your desired maximum number of one hot columns is not valid, setting to be the current maximum number of one hot columns.
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : LOW_BP , NodeID : 10
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 9
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 8
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Back Tracking!!
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# current_dp:  [Rule(feature='HIGH_BP', operator='>', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 5
# Back Tracking!!
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# current_dp:  [Rule(feature='HIGH_BP', operator='>', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 4
# Back Tracking!!
# current_dp:  [Rule(feature='HIGH_BP', operator='>', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64')), Rule(feature='Age', operator='>', threshold=50.5, feature_type=dtype('int64'))]
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Back Tracking!!
# current_dp:  [Rule(feature='HIGH_BP', operator='>', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Back Tracking!!
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Na_to_K , NodeID : 1
# All nodes visited
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : LOW_BP , NodeID : 10
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 9
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 8
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Back Tracking!!
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 5
# Back Tracking!!
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 4
# Back Tracking!!
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Back Tracking!!
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Back Tracking!!
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Na_to_K , NodeID : 1
# All nodes visited
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# current_dp:  [Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# current_dp:  [Rule(feature='HIGH_BP', operator='<=', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : LOW_BP , NodeID : 10
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# current_dp:  [Rule(feature='HIGH_BP', operator='<=', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 9
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : HIGH_Cholesterol , NodeID : 8
# Back Tracking!!
# Branch: right, Node type : inter , Feature : HIGH_Cholesterol ,  Parent : LOW_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 7
# Back Tracking!!
# Branch: left, Node type : inter , Feature : LOW_BP ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 6
# Back Tracking!!
# current_dp:  [Rule(feature='HIGH_BP', operator='<=', threshold=0.5, feature_type=dtype('O')), Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# current_dp:  [Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Branch: left, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 5
# Back Tracking!!
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Age , NodeID : 4
# Back Tracking!!
# Branch: right, Node type : inter , Feature : Age ,  Parent : HIGH_BP , Left Child : HIGH_Cholesterol , Right Child : HIGH_Cholesterol , NodeID : 3
# Back Tracking!!
# Branch: left, Node type : inter , Feature : HIGH_BP ,  Parent : Na_to_K , Left Child : LOW_BP , Right Child : Age , NodeID : 2
# Back Tracking!!
# current_dp:  [Rule(feature='Na_to_K', operator='<=', threshold=14.828500270843506, feature_type=dtype('float64'))]
# Branch: root, Node type : root , Feature : Na_to_K ,  Parent : Na_to_K , Left Child : HIGH_BP , Right Child : HIGH_Cholesterol , NodeID : 0
# Branch: right, Node type : leaf , Feature : HIGH_Cholesterol , Parent : Na_to_K , NodeID : 1
# All nodes visited

# %%
# show sample summary df
summary_dic['summary 2']
# Out:
#                          interested_class  base_rate  feature operator  \
# decision 0 constraint 0                 3         10  Na_to_K       <=
# decision 1 constraint 0                 3         10  HIGH_BP       <=
#            constraint 1                 3         10  Na_to_K       <=
#
#                          threshold  total_sample_size  \
# decision 0 constraint 0    14.8285                 84
# decision 1 constraint 0     0.5000                 51
#            constraint 1    14.8285                 84
#
#                          interested_class_sample_size  target_lift  \
# decision 0 constraint 0                            38            2
# decision 1 constraint 0                            38            2
#            constraint 1                            38            2
#
#                          actual_lift data type
# decision 0 constraint 0         4.52   float64
# decision 1 constraint 0         7.45    object
#            constraint 1         4.52   float64
